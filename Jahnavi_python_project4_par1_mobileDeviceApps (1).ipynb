# %% [markdown]
# # Question 1

# %%
#Numerical libraries
import numpy as np

# to handle data in form of rows and columns
import pandas as pd

# importing ploting libraries
import matplotlib.pyplot as plt
import matplotlib.style 

# statistical plots
import seaborn as sns

# %%
# reading the dataset

data = pd.read_csv("C:/Users/jahna/Downloads/Apps_data+(1).csv")

# %% [markdown]
# # Question 2

# %%
# reading the sample

data.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
# information of the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# shape of the dataset

data.shape
# Out:
# (10841, 13)

# %% [markdown]
# # Question 3

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# # The columns that need to be worked upon for model building are
#
# Missing Values, outliers, Data types, categorical variables, target variables

# %% [markdown]
# # Question 4

# %%
# Checking if there are any duplicate records in the dataset

duplicates = data.duplicated()
print("The number of duplicate records are:",duplicates.sum())
# Out:
# The number of duplicate records are: 483

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Question 5
# 5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them

# %%
# checking and printing the unique categories

unique_categories = data['Category'].unique
print("The unique categories are \n", unique_categories,"\n\n")

# using boolean indexing to filter out invalid categories from the dataset.
invalid_categories = ['invalid_category1', 'invalid_category2']
data = data[~data['Category'].isin(invalid_categories)]

# printing the unique categories after dropping the invalid category
unique_categories = data['Category'].unique()
print("Unique Categories after dropping invalid categories:\n", unique_categories)
# Out:
# The unique categories are
#  <bound method Series.unique of 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10358, dtype: object>
#
#
# Unique Categories after dropping invalid categories:
#  ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']

# %% [markdown]
# # Question 6

# %%
# checking the number of missing values using 'isnull' function

print("The number of missing values in the rating column are:",data['Rating'].isnull().sum())
data.dropna(subset = ['Rating'], inplace = True)

# create a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

data['Rating_category'] = ['high' if rating > 3.5 else 'low' for rating in data['Rating']]
# Out:
# The number of missing values in the rating column are: 1465

# %% [markdown]
# # Question 7

# %%
# The distribution of the newly created column 'Rating_category' and comment on the distribution.

rating_category_counts =data['Rating_category'].value_counts()
print("The count of rating_categories are \n",rating_category_counts)

percentage_dist = rating_category_counts / len(data) * 100
print("The percentage of count of rating_categories are \n",percentage_dist)
# Out:
# The count of rating_categories are
#  high    8013
# low      880
# Name: Rating_category, dtype: int64
# The percentage of count of rating_categories are
#  high    90.104577
# low      9.895423
# Name: Rating_category, dtype: float64

# %% [markdown]
# The majority of the apps (90%) are categorized as 'High' rating, while the remaining 10% are categorized as 'Low' rating. This indicates that a significant proportion of the apps in the dataset have received ratings above the threshold of 3.5, suggesting that they are generally well-received."

# %% [markdown]
# # Question 8

# %%
#  Convert the column "Reviews" to numeric data type
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce')

# checking the presence of outliers in the column
sns.boxplot(data['Reviews'])
plt.xlabel('Reviews')
plt.show()

# handling the outliers using log transformation approach
data['Reviews'] = data['Reviews'].apply(lambda x: np.log1p(x))

# %% [markdown]
# # Question 9

# %%
# Converting the column 'Size' with alphanumeric to numbers and converting into suitable data type

data['Size'] = data['Size'].replace('M','1000000')
data['Size'] = data['Size'].replace('K','1000')
data['Size'] = data['Size'].replace('Varies with device','1000000')

# The errors='coerce' parameter ensures that any non-numeric values are converted to NaN.
data['Size'] = pd.to_numeric(data['Size'], errors='coerce')
data = data.dropna(subset=['Size'])

# %% [markdown]
# # Question 10

# %%
# Check the column 'Installs' and treating the unwanted characters and convert the column into a suitable data type.

# The str.replace() function is used to replace the unwanted characters with an empty string.
data['Installs'] = data['Installs'].str.replace(',', '')
data['Installs'] = data['Installs'].str.replace('+', '')
data['Installs'] = pd.to_numeric(data['Installs'], errors='coerce')
data['Installs'].dtype
# Out:
# C:\Users\jahna\AppData\Local\Temp\ipykernel_11688\1780874496.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Installs'] = data['Installs'].str.replace('+', '')
# dtype('int64')

# %%
data['Installs'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Question 11

# %%
# Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

data['Price'] = data['Price'].str.replace('$','')
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')
# Out:
# C:\Users\jahna\AppData\Local\Temp\ipykernel_11688\4060742694.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Price'] = data['Price'].str.replace('$','')

# %% [markdown]
# # Question 12

# %%
# drop the unwanted columns'

data = data.drop(columns = [ 'App', 'Rating' ,'Last Updated','Current Ver','Android Ver','Genres'])

# %% [raw]
# dropping the columns 'App', 'Rating' ,'Last Updated', 'Current Ver','Android Ver' which are redundant for our analysis

# %%
data.dtypes
# Out:
# Category            object
# Reviews            float64
# Size               float64
# Installs             int64
# Type                object
# Price              float64
# Content Rating      object
# Rating_category     object
# dtype: object

# %% [markdown]
# # Question 13

# %%
# Encode the categorical columns.

data = pd.get_dummies(data, columns=['Category', 'Type', 'Content Rating'], drop_first=True)
data.head()
# Out:
#       Reviews       Size  Installs  Price Rating_category  \
# 37  10.508896  1000000.0   5000000    0.0            high
# 42  12.595483  1000000.0  10000000    0.0            high
# 52   9.744375  1000000.0   1000000    0.0            high
# 67  10.601921  1000000.0   5000000    0.0            high
# 68   5.877736  1000000.0    100000    0.0            high
#
#     Category_AUTO_AND_VEHICLES  Category_BEAUTY  Category_BOOKS_AND_REFERENCE  \
# 37                           0                0                             0
# 42                           0                0                             0
# 52                           1                0                             0
# 67                           1                0                             0
# 68                           1                0                             0
#
#     Category_BUSINESS  Category_COMICS  ...  Category_SPORTS  Category_TOOLS  \
# ...

# %% [markdown]
# # Question 14

# %%
# Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
# Segregate the target variable
target = data['Rating_category']

# Segregate the independent features
independent_features = data.drop('Rating_category', axis=1)

# %% [markdown]
# # Question 15

# %%
# Split the dataset into train and test.

# %%
from sklearn.model_selection import train_test_split
data_train, data_test = train_test_split(data, train_size = 0.70, test_size = 0.30)

# %%
# splitting the dataset into train data

y_train = data_train.pop('Rating_category')
X_train = data_train

print(X_train.shape, y_train.shape)
# Out:
# (1027, 41) (1027,)

# %%
y_test = data_test.pop('Rating_category')
X_test = data_test

print(X_test.shape, y_test.shape)
# Out:
# (441, 41) (441,)

# %% [markdown]
# # Question 16

# %%
# Standardize the data, so that the values are within a particular range.

# %%
# Rescaling the features

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Fit the scaler to the training data
train_scaled = scaler.fit_transform(X_train)

# Apply the scaler to the test data
test_scaled = scaler.transform(X_test)
